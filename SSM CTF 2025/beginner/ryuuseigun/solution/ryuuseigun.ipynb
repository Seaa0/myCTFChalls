# %% [markdown]
# # ryuuseigun (Beginner)
# You will notice that you have received a html file. This is a rather unique kind of crypto challenge, as challenges normally involve python files that are being ran by the challenge author (see `Beginner/Cheater`, or python oracles that you can `nc` to.
#
# Let us first take a look a the website when opened.

# %% [markdown]
# ![image.png](attachment:d3730d44-ea0f-42b2-854f-2f7bc5ac174c.png)
#
# As you can see, the target seems to be to get the year to be `100000000000000`, which is when the points will show something of use, perhaps writing out the flag.

# %% [markdown]
# Let us now take a look at the html code.

# %%
# Note: please don't run this code, Jupyter Notebook uses python, and this is written in html.
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>ryuuseigun</title>
    <link rel="preconnect" href="https://fonts.googleapis.com">
    <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
    <link href="https://fonts.googleapis.com/css2?family=IBM+Plex+Sans:ital,wght@0,100;0,200;0,300;0,400;0,500;0,600;0,700;1,100;1,200;1,300;1,400;1,500;1,600;1,700&display=swap" rel="stylesheet">
</head>
<body>
        <div class="main">
            <canvas width=1024 height=1024 id="stars">
            </canvas>
            <div class="header">
                <i>ryuuseigun</i><br>
                these stars follow such unique, elliptical orbits!<br>
                i wonder what will they look like <span style="color: red">100000000000000</span> years from now?<br>
                <span id="year">year: 1</span><br>
                <button onclick="nextyear()">next year</button>
            </div>


        </div>
</body>
</html>

<style>
    button {
        background-color: white;
        color: black;
        border: none;
        font-size: 20px;
        padding: 5px;
        margin-top: 10px;
        cursor: pointer;
        transition: 0.3s;
    }

    button:hover {
        filter: invert(1);
    }
    .main {
        width: 80%;
        margin: auto;
        display: flex;
        justify-content: center;
    }

    html {
        background-color: black;
        color: white;
    }

    .header {
        position: absolute;
        background-color: rgba(0, 0, 0, 0.7);
        color: #ececec;
        font-size: 25px;
        top: 50%;
        transform: translate(0, -50%);
        padding: 20px;
        font-family: 'IBM Plex Sans'
    }
</style>

<script>
    var points = [[4936, 5893], [20, 3208], [7094, 3190], [7094, 4989], [1161, 6757], [4487, 4814], [6639, 1789], [6639, 6390], [1155, 6540], [1155, 1639], [5105, 5333], [2556, 5655], [3029, 841], [4299, 3719], [4299, 4460], [5383, 210], [7935, 1344], [6655, 2556], [6655, 5623], [7010, 3662], [1803, 7829], [6814, 1904], [2211, 5846], [2801, 5236], [6148, 7673], [6389, 7907], [6638, 6962], [6638, 1217], [7863, 3141], [5373, 3635], [5373, 4544], [5732, 3517], [5732, 4662], [1946, 302], [3618, 7809], [3618, 370], [4219, 6104], [4824, 5715], [4824, 2464], [2724, 1190], [2724, 6989], [6937, 1297], [6937, 6882], [2545, 6586], [4412, 5713], [4412, 2466], [4090, 5821], [5923, 8067], [1551, 2574], [3786, 7044], [277, 657], [4173, 2857], [797, 4313], [797, 3866], [4633, 6933], [4633, 1246], [7757, 5127], [8112, 4682], [5037, 4858], [414, 3606], [414, 4573], [2930, 1864], [2646, 1841], [7235, 5327], [1875, 6417], [8066, 5893], [1157, 4676], [1238, 2018], [1238, 6161], [2349, 3176], [3402, 2565], [5929, 4093], [2455, 1854], [5730, 2209], [5730, 5970], [3510, 6122], [5607,
 4462], [2749, 5899], [1662, 6075], [7628, 1009], [5450, 6846], [1348, 375], [6064, 5158], [2310, 4792], [300, 3966], [4704, 6936], [7121, 154], [832, 7154], [5821, 263], [4326, 2768], [1696, 2713], [5520, 1411], [5893, 966], [297, 4320], [5943, 1207], [663, 5083], [2389, 8078], [6420, 4928], [6191, 3261], [7050, 2827], [804, 4812], [6971, 3295], [7135, 8086], [2595, 3158], [6769, 8109], [1896, 4659], [2710, 4251], [1077, 7278], [419, 1677], [6946, 2521], [5703, 5199], [6357, 4179], [7574, 5169], [4190, 3554], [1919, 4022], [899, 8010], [6333, 7054], [401, 3368], [5768, 2119], [206, 6884], [2476, 1933], [1397, 4310], [3383, 3384], [3032, 1568], [1686, 2246], [1509, 470], [5353, 2118], [1360, 6107], [1550, 5149], [2554, 7077], [4317, 123], [3876, 3319], [5561, 4685], [5510, 6009], [710, 6546], [4076, 4541], [2923, 1901], [1154, 3314], [1850, 4406], [4432, 4097]]

    const canvas = document.getElementById('stars')
    const ctx = canvas.getContext('2d');

    window.addEventListener("DOMContentLoaded", function() {
        ctx.fillStyle = 'black';
        ctx.fillRect(0, 0, 1024, 1024);
        points.forEach(point => {
            ctx.fillStyle = 'yellow';
            ctx.fillRect((point[0] / 8 | 0), 1024 - (point[1] / 8 | 0), 5, 5);
        })
    })

    const p = 0x1ff3
    const a = 0x18ba
    const b = 0x197d

    class Point {
        constructor(x, y) {
            this.x = x;
            this.y = y;
        }

        isInfinity() {
            return this.x === null && this.y === null;
        }

        equals(other) {
            return this.x === other.x && this.y === other.y;
        }
    }

    class EllipticCurve {
        constructor(a, b, p) {
            this.a = a; 
            this.b = b; 
            this.p = p; 
        }

        add(p1, p2) {
            if (p1.isInfinity()) return p2;
            if (p2.isInfinity()) return p1;

            if (p1.equals(p2)) {
                return this.double(p1);
            }

            if (p1.x === p2.x) {
                return new Point(null, null);
            }

            const lambda = this.mod((p2.y - p1.y) * this.inverseMod(p2.x - p1.x, this.p), this.p);
            const x3 = this.mod(lambda * lambda - p1.x - p2.x, this.p);
            const y3 = this.mod(lambda * (p1.x - x3) - p1.y, this.p);

            return new Point(x3, y3);
        }

        double(p) {
            if (p.isInfinity()) return p;

            const lambda = this.mod((3 * p.x * p.x + this.a) * this.inverseMod(2 * p.y, this.p), this.p);
            const x3 = this.mod(lambda * lambda - 2 * p.x, this.p);
            const y3 = this.mod(lambda * (p.x - x3) - p.y, this.p);

            return new Point(x3, y3);
        }

        inverseMod(a, m) {
            let [oldR, r] = [a, m];
            let [oldS, s] = [1, 0];
            let [oldT, t] = [0, 1];

            while (r !== 0) {
                const quotient = Math.floor(oldR / r);
                [oldR, r] = [r, oldR - quotient * r];
                [oldS, s] = [s, oldS - quotient * s];
                [oldT, t] = [t, oldT - quotient * t];
            }

            return oldS < 0 ? oldS + m : oldS;
        }

        mod(n, m) {
            return ((n % m) + m) % m;
        }
    }

    const curve = new EllipticCurve(a, b, p);
    const p1 = new Point(points[0][0], points[0][1]);
    const p2 = new Point(points[1][0], points[1][1]);

    function move(point, K) {
        let p = new Point(point[0], point[1])
        for (let i = 0; i < K - 1; i++) {
            const q = new Point(point[0], point[1])
            p = curve.add(p, q)
        }
        return p;
    }

    function move_all_points(i) {
        ctx.fillStyle = 'black';
        ctx.fillRect(0, 0, 1024, 1024);
        points.forEach(point => {
            var add_point = move(point, i)
            console.log(add_point)
            ctx.fillStyle = 'yellow';
            ctx.fillRect((add_point.x / 8 | 0), 1024 - (add_point.y / 8 | 0), 5, 5);
        })
    }

    var year = 1;

    function nextyear() {
        year++;
        move_all_points(year);
        document.getElementById('year').innerText = `year: ${year}`
    }

</script>

<style>
    canvas {
        background-color: 2px solid black;
    }
</style>

# %% [markdown]
# After looking through, we realise that the part that is actually cryptographically-related is this:

# %%
const p = 0x1ff3
const a = 0x18ba
const b = 0x197d

class Point {
    constructor(x, y) {
        this.x = x;
        this.y = y;
    }

    isInfinity() {
        return this.x === null && this.y === null;
    }

    equals(other) {
        return this.x === other.x && this.y === other.y;
    }
}

class EllipticCurve {
    constructor(a, b, p) {
        this.a = a; 
        this.b = b; 
        this.p = p; 
    }

    add(p1, p2) {
        if (p1.isInfinity()) return p2;
        if (p2.isInfinity()) return p1;

        if (p1.equals(p2)) {
            return this.double(p1);
        }

        if (p1.x === p2.x) {
            return new Point(null, null);
        }

        const lambda = this.mod((p2.y - p1.y) * this.inverseMod(p2.x - p1.x, this.p), this.p);
        const x3 = this.mod(lambda * lambda - p1.x - p2.x, this.p);
        const y3 = this.mod(lambda * (p1.x - x3) - p1.y, this.p);

        return new Point(x3, y3);
    }

    double(p) {
        if (p.isInfinity()) return p;

        const lambda = this.mod((3 * p.x * p.x + this.a) * this.inverseMod(2 * p.y, this.p), this.p);
        const x3 = this.mod(lambda * lambda - 2 * p.x, this.p);
        const y3 = this.mod(lambda * (p.x - x3) - p.y, this.p);

        return new Point(x3, y3);
    }

    inverseMod(a, m) {
        let [oldR, r] = [a, m];
        let [oldS, s] = [1, 0];
        let [oldT, t] = [0, 1];

        while (r !== 0) {
            const quotient = Math.floor(oldR / r);
            [oldR, r] = [r, oldR - quotient * r];
            [oldS, s] = [s, oldS - quotient * s];
            [oldT, t] = [t, oldT - quotient * t];
        }

        return oldS < 0 ? oldS + m : oldS;
    }

    mod(n, m) {
        return ((n % m) + m) % m;
    }
}

const curve = new EllipticCurve(a, b, p);
const p1 = new Point(points[0][0], points[0][1]);
const p2 = new Point(points[1][0], points[1][1]);

function move(point, K) {
    let p = new Point(point[0], point[1])
    for (let i = 0; i < K - 1; i++) {
        const q = new Point(point[0], point[1])
        p = curve.add(p, q)
    }
    return p;
}

function move_all_points(i) {
    ctx.fillStyle = 'black';
    ctx.fillRect(0, 0, 1024, 1024);
    points.forEach(point => {
        var add_point = move(point, i)
        console.log(add_point)
        ctx.fillStyle = 'yellow';
        ctx.fillRect((add_point.x / 8 | 0), 1024 - (add_point.y / 8 | 0), 5, 5);
    })
}

var year = 1;

function nextyear() {
    year++;
    move_all_points(year);
    document.getElementById('year').innerText = `year: ${year}`
}

# %% [markdown]
# Firstly, the `nextyear()` function calls the `move_all_points(year)` function, which in turn calls the `move(point,i)` function.
# Upon closer analysis, we notice that the `move(point,i)` function seems to be continuously adding a point to itself.
#
# But wait... how do we add points? This is where we introduce **Elliptic Curves**. Elliptic Curves have a special point addition operation. We won't dive into the details, but you can learn more [here](https://cryptohack.org/courses/elliptic/course_details/).
# Evidently, our task is now to implement point addition `100000000000000` times. You may think, then why don't we just click the button, if running the code will take the same time anyway? You would be right. However, just like how $a+a+a = 3\times a$ in regular math, that applies to elliptic curves' point addition as well!
# So, how do we implement it? We can either implement it from scratch, or we can use a neat python extension called `SageMath`. We say "extension" and not "library" because this isn't a python library, it is literally a programming language that builds on python.
# You may download `SageMath` [here](https://doc.sagemath.org/html/en/installation/index.html). Please select the "no development" option under your operating system.

# %% [markdown]
# Now that you've downloaded SageMath, you can restart JupyterLab. After restarting, on the top right hand corner, you will see something that says "Python 3 (ipykernel)", or something along those lines. Click it, and select `SageMath <latest version number>`. Congratulations, you have successfully installed SageMath!
#
# Note: if you wish to use SageMath outside JupyterLab, you may do so by either
# - Creating `.sage` files and running them with `sage example.sage` in the terminal
# - or using `.py` files, adding `from sage.all import <whatever you want to import, if unsure just import *>` at the start, and running the file with `sage example.py` in the terminal
#
# Please note that `.py` and `.sage` files behave slightly differently in terms of syntax, but nothing to worry about.
#
# Now, let us implement Elliptic Curve Scalar Multiplication.
# In SageMath, elliptic curves are defined by `EllipticCurve(Field/Ring,parameters)`.
# In this case, the field will be the Galois Field of $p$, of `GF(p)` in SageMath, where $p$ is a prime. Galois Fields can get incredibly theoretical if $p$ is a prime power and not a power, but for the case where $p$ is prime, `GF(p)` behaves the same as `Zmod(p)`, which is the ring of integers modulo $p$, or simply put, integers modulo $p$. In this case, we pick `GF(p)` instead of `Zmod(p)` as that is best practice, allowing you to use functions such as `EllipticCurve.order()`, which are useful for elliptic curve cryptography CTF challenges.
# Next, our parameters will be $a$ and $b$, where `y^2=x^3+ax+b`, which is the standard equation defining an elliptic curve. Feel free to plot it on a graphing calculator to see the beauty of the curve. SageMath takes in these parameters in the form of a tuple or list, `(a,b)` or `[a,b]`.
# In the html code given, there are 3 lines that provide us with very useful information.
# `const p = 0x1ff3`
# `const a = 0x18ba`
# `const b = 0x197d`
# Now, we have everything necessary to define the elliptic curve! Feel free to use the space below to place your code.

# %%
# feel free to code here
p = 0x1ff3
a = 0x18ba
b = 0x197d
E = EllipticCurve(GF(p),(a,b))

# %% [markdown]
# Now that we have defined the elliptic curve, we now need to define the points on the curve. SageMath allows you to create `Elliptic Curve Point Objects`, which allow you to perform scalar multiplication on them. How do you define them though? Say we named the elliptic curve object `E`. We can define a point with coordinates $(x,y)$ as `E(x,y)` in the code. Recall that in the html code, we were provided with the list of points that we needed, in the line `var points = [[4936, 58...`.
4468], [6916, 5543], [7824, 26], [4597, 5727], [3945, 7680], [3945, 499], [7645, 7540], [7208, 7142], [7494, 7846], [1706, 4958], [5791, 73], [3643, 7169], [7265, 1626], [2064, 5683], [6385, 5846], [4211, 2666], [4351, 1218], [7449, 2710], [7945, 2381], [5150, 4522], [581, 3833], [1271, 7145], [5660, 1928], [6207, 708], [3693, 6856], [6932, 7969], [4606, 2878], [7489, 7587], [3449, 3162], [4521, 701], [5534, 3708], [215, 3539], [3504, 6329], [7635, 6619], [2771, 78], [792, 1288], [7118, 1978], [4096, 1039], [3170, 8046], [6786, 4527], [2115, 7962], [1735, 7158], [6133, 3448], [4435, 851], [1899, 1754], [502, 8116], [1864, 2380], [320, 899], [7416, 7017], [371, 4220], [889, 2129], [2458, 8061], [7838, 6841], [2675, 3754], [4483, 1537], [4820, 550], [1978, 6427], [7718, 5350], [4353, 5374], [5808, 7488], [438, 4808], [4876, 5261], [8124, 6910], [8124, 1269], [337, 7], [8101, 737], [5844, 3871], [4531, 463], [4531, 7716], [83, 5196], [3223, 7989], [15, 1954], [15, 6225], [2543, 593], [80, 455], [4392, 262], [1731, 6210], [4486, 3508], [2260, 2586], [3189, 1660], [6944, 7723], [5283, 4476], [3139, 4008], [1904, 614], [4798, 1550], [3957, 4462], [2749, 5899], [1662, 6075], [7628, 1009], [5450, 6846], [1348, 375], [6064, 5158], [2310, 4792], [300, 3966], [4704, 6936], [7121, 154], [832, 7154], [5821, 263], [4326, 2768], [1696, 2713], [5520, 1411], [5893, 966], [297, 4320], [5943, 1207], [663, 5083], [2389, 8078], [6420, 4928], [6191, 3261], [7050, 2827], [804, 4812], [6971, 3295], [7135, 8086], [2595, 3158], [6769, 8109], [1896, 4659], [2710, 4251], [1077, 7278], [419, 1677], [6946, 2521], [5703, 5199], [6357, 4179], [7574, 5169], [4190, 3554], [1919, 4022], [899, 8010], [6333, 7054], [401, 3368], [5768, 2119], [206, 6884], [2476, 1933], [1397, 4310], [3383, 3384], [3032, 1568], [1686, 2246], [1509, 470], [5353, 2118], [1360, 6107], [1550, 5149], [2554, 7077], [4317, 123], [3876, 3319], [5561, 4685], [5510, 6009], [710, 6546], [4076, 4541], [2923, 1901], [1154, 3314], [1850, 4406], [4432, 4097]]
Epoints = []
for point in points:
    Epoints.append(E(*point))

# %% [markdown]
# Now that you have all the points, performing scalar multiplication is trivial. Given a point P, $100000000000000\times P$ can be written as `100000000000000*P` in SageMath. You will also want to extract a tuple of the x and y values by using `P.xy()`, so that the values can be read more easily. For e.g., SageMath prints a point $(x,y)$ in the form `(x:y:0)`, which is hard for python libraries, which we are using later, to read. Try it out!

# %%
# feel free to code here
multPoints = []
for point in Epoints:
    multPoints.append((100000000000000*point).xy())

# %% [markdown]
# When you get all the points, since this is not the key part of what we are teaching you in this challenge, you can use the code we provide below to retrieve the flag.

# %%
import matplotlib.pyplot as plt
points = multPoints # list of points' x and y values
for point in points:
    plt.plot(*point, 'bo')
plt.show()
